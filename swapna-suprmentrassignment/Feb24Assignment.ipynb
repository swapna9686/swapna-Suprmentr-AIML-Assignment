# %%
import pandas as pd

# %%
df=pd.read_csv("true_detective_episodes.csv")

# %%
print("Top 5 rows:")
df.head(5)
# Out:
# Top 5 rows:
#    season  episode_num_in_season  episode_num_overall  \
# 0       1                      1                    1
# 1       1                      2                    2
# 2       1                      3                    3
# 3       1                      4                    4
# 4       1                      5                    5
#
#                          title         directed_by      written_by  \
# 0         The Long Bright Dark  Cary Joji Fukunaga  Nic Pizzolatto
# 1                Seeing Things  Cary Joji Fukunaga  Nic Pizzolatto
# 2              The Locked Room  Cary Joji Fukunaga  Nic Pizzolatto
# 3               Who Goes There  Cary Joji Fukunaga  Nic Pizzolatto
# 4  The Secret Fate of All Life  Cary Joji Fukunaga  Nic Pizzolatto
#
#   original_air_date  us_viewers
# 0        2014-01-12   2330000.0
# 1        2014-01-19   1670000.0
# 2        2014-01-26   1930000.0
# 3        2014-02-09   1990000.0
# 4        2014-02-16   2250000.0

# %%
print("Highest value in each column:")
print(df.max(numeric_only=True))
# Out:
# Highest value in each column:
# season                         3.0
# episode_num_in_season          8.0
# episode_num_overall           24.0
# us_viewers               3520000.0
# dtype: float64

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# season                   0
# episode_num_in_season    0
# episode_num_overall      0
# title                    0
# directed_by              0
# written_by               0
# original_air_date        0
# us_viewers               0
# dtype: int64

# %% [markdown]
# #5 insights
#
# 1.The dataset contains multiple columns with different type of information
#
# 2.The max values shows the highest recorded values for numeric features
#
# 3.The dataset contains no null values
#
# 4.Viewing the top rows to understand the dataset structure
#
# 5.Using the Dataframe from pandas library helps us to identify patterns
