# %% [markdown]
# ML problems
#
# 1.college- In colleges Teaching is good but it would be more useful if they teach us using animation videos intead of normal teaching to help us remember what we study
#
# 2.healthcare- If a patient is in emergency instead of filling a last min form,it would be better access the details of the patient through the stored patients data
#
# 3.shopping-instead of waiting in a long line to buy the grociers the best way is to use digital scanner to scan their own products and pay accordingly

# %% [markdown]
# 1.input: projector content->output: Generated animation videos explaining the concept
#
# 2.input: Patient ID/fingerprint/name->output: automatically retrieves patients data
#
# 3.input: Products scannes by the customer->output: Automatic bill generation and payment
