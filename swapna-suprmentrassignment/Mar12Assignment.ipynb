# %% [raw]
#                           Weather?
#                           /     \
#                      Sunny     Rainy
#                        /           \
#                 Humidity High?    Windy?
#                       /   \       /  \
#                     Yes    No   Yes   No
#                    Dont   play  Dont  play
#                    play         play
