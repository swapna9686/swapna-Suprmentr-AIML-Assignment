# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("Marketing.csv")
plt.plot(months,revenue,color='Black',ls='-',lw=0.8,marker='o',mec='blue',mfc='orange')
plt.title("Monthly Revenue")
plt.xlabel("Months")
plt.ylabel("Revenue")
plt.show()

# %%
plt.scatter(marketing,profit,cmap='viridis',alpha=1.0)
plt.colorbar()
plt.title("Marketing vs Profit")
plt.xlabel("Marketing")
plt.ylabel("Profit")
plt.show()
# Out:
# C:\Users\swapn\AppData\Local\Temp\ipykernel_9652\76654565.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(marketing,profit,cmap='viridis',alpha=1.0)

# %%
import seaborn as sns
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title("Correlational Matrix")
plt.show()

# %% [markdown]
# #Insights
#
# Revenue shows fluctuations across months and month may has highest revenue
#
# The scatter plot indicates that higher marketing spend generally leads to higher profit
#
# The correaltion heatmap shows a strong positive correlation between marketing spent and profit
