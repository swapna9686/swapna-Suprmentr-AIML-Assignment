# %% [markdown]
# 10 Real life AI applications
#
# 1.Chatgpt: Uses Machine Learning models to understand the user questions and generate human like responses
#
# 2.Google Gemini: Uses Deep Learning to understand the user inputs and provide intelligent answers or suggestions
#
# 3.Alexa: Uses speech recognition and ML algorithms to understand voice commands and fulfills the requirement
#
# 4.Meta AI: uses ML algorithms to analyze user behavior and provide personalized suggestions
#
# 5.Youtube Recommendations: uses ML algorithms to analyze intersets and watch history to recommend videos
#
# 6.Netflix suggestions: uses ML to study viewing history,downloads and user preference to recommend movies and TV shows
#
# 7.Gmail spam folder:uses ML models to classify the recieved meassage as spam or not spam
#
# 8.Face unlock: Uses AI and computer vision to recognize the human's face and unlocks the device securely
#
# 9.Fingerprint Recognition: Uses pattern recognition and ML to compare fingerprint patterns with the stored data for authentication
#
# 10.Google Map: Uses ML to analyze traffic data and user locations to suggest the fastest route
