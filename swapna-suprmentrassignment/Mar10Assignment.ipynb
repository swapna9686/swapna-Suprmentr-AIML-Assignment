# %% [markdown]
# #spam classifier thinking
#
# A spam detection system requires:
#
# 1.A spam detection system which analyzes features like suspicious words,links and email length
#
# 2.The model should be trained on labeled emails(spam or not spam)
#
# 3.Spam classifies into 2 types of mistakes:
#
#   1.False positive: Normal email marked as spam
#
#   2.False Negative: Spam email marked as normal
