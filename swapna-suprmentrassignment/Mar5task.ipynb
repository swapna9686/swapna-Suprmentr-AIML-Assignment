# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data={
    "Age":[22,23,24,45,46,47,30,31,32],
    "Annual_Income":[50,60,80,90,88,95,100,65,62],
    "Spending_score":[5,6,3,9,13,20,20,12,15]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Age  Annual_Income  Spending_score
# 0   22             50               5
# 1   23             60               6
# 2   24             80               3
# 3   45             90               9
# 4   46             88              13
# 5   47             95              20
# 6   30            100              20
# 7   31             65              12
# 8   32             62              15

# %%
plt.scatter(df['Annual_Income'],df['Spending_score'])
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.title('Mall customer segmentation data')
plt.show()

# %%
kmeans=KMeans(n_clusters=3)
kmeans.fit(df)
# Out:
# C:\Users\swapn\Documents\swapn\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
plt.scatter(df['Annual_Income'],df['Spending_score'],c=labels)
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.title('KMeans mall customer segmentation data')
plt.show()

# %%
labels=kmeans.labels_
print(labels)
# Out:
# [1 1 2 0 0 0 0 1 1]

# %%
centroids=kmeans.cluster_centers_
print(centroids)
# Out:
# [[42.   93.25 15.5 ]
#  [27.   59.25  9.5 ]
#  [24.   80.    3.  ]]

# %%
plt.scatter(df['Annual_Income'],df['Spending_score'],c=labels)
plt.scatter(centroids[:,1],centroids[:,2],marker='X',s=200)
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()
