# %%
import string
stopwords=["is","the","and","in","to","of","i","but"]

def clean_text(text):
    text.lower()

    text=text.translate(str.maketrans('','',string.punctuation))

    text=text.encode('ascii','ignore').decode()

    words=text.split()
    cleaned=[word for word in words if word not in stopwords]

    return " ".join(cleaned)

text=input("Enter text:")
print("Cleaned Text:",clean_text(text))
# Out:
# Enter text: "i luv coding 💻🔥 but sometimes error comes 😭"
# Cleaned Text: luv coding sometimes error comes
