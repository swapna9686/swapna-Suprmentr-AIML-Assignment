# %%
tasks={
    "Resume":[
        "Write a Resume",
        "Write a professional resume for a cs student with skills python,ML and projects"
    ],
    "Business Idea":[
        "Give business idea",
        "Suggest a profitable startup idea for college students in India with low investment"
    ],
    "Study Plan":[
        "Make study plan",
        "Create a 7-day study plan for preparing interview covering aptitude,coding and reasoning"
    ]
}
for task,prompts in tasks.items():
    print(f"\nTask:{task}")
    print("Weak Prompt:",prompts[0])
    print("Strong Prompt:",prompts[1])
# Out:
# Task:Resume
# Weak Prompt: Write a Resume
# Strong Prompt: Write a professional resume for a cs student with skills python,ML and projects
#
# Task:Business Idea
# Weak Prompt: Give business idea
# Strong Prompt: Suggest a profitable startup idea for college students in India with low investment
#
# Task:Study Plan
# Weak Prompt: Make study plan
# Strong Prompt: Create a 7-day study plan for preparing interview covering aptitude,coding and reasoning
