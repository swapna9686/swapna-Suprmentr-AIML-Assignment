# %%
name=input("Enter user name: ")
age=int(input("Enter user age: "))
hobby=input("Enter user hobby: ")
def personalized_suggestion(name,age,hobby):
    if age<=5:
        category="Child"
        message="Play and eat heathly"
    elif age<=12:
        category="Kid"
        meassage="Watch good cartoons and listen to stories"
    elif age<=20:
        category="Teenager"
        message="Enjoy Video Games,Trending music and focus on studies"
    elif age<=60:
        category="Adult"
        message="Focus on career,travel and professional courses"
    elif age<=100:
        category="Senior"
        message="take care of your health and stay happy"
    else:
        category="Invalid"
        message="Invalid Age"

    print("Hello", name)
    print("Age category:", category)
    print("Suggestion:", message)
suggestion=personalized_suggestion(name,age,hobby)
# Out:
# Enter user name:  swapna
# Enter user age:  22
# Enter user hobby:  dancing
# Hello swapna
# Age category: Adult
# Suggestion: Focus on career,travel and professional courses
