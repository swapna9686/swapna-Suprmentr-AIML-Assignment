# %% [markdown]
# prompts={
#
#     "1.Explain something but do not use any words",
#
#     "2.Give me a answer which is both correct and wrong",
#
#     "3.Translate this sentence into the same language",
#
#     "4.Tell me something and nothing at the same time",
#
#     "5.Write a sentence that contradicts itself"
# }
#
# Responses from AI={
#
#     1.🌧️➡️🌱➡️🌳➡️🍎
#
#     2.The answer is correct in one interpretation and wrong in another.
#
#     3.Translate this sentence into the same language.
#
#     4.I am saying something, but it contains no meaningful information.
#
#     5.This sentence is false.
# }
#
# Observations={
#
#     1.AI avoids words by using symbols,but still communicates meaning
#
#     2.AI does not give a truly contradictory answer but instead explains the contradiction
#
#     3.AI returns the same sentence correctly,showing it understands the instruction
#
#     4.AI tries to balance both conditions but cannot fully satify them
#
#     5.AI understands logical contradictions but does not resolve them
# }
