# %%
#python Lists
import time
size=1000000
list1=list(range(size))
list2=list(range(size))
list3=list(range(size))
start=time.time()
result=[x+y+z for x,y,z in zip(list1,list2,list3)]
print("python:",time.time()-start)

#Numpy 
import numpy as np
a=np.arange(size)
b=np.arange(size)
c=np.arange(size)
start=time.time()
d=a+b+c
print("numpy:",time.time()-start)
# Out:
# python: 0.2903294563293457
# numpy: 0.00409388542175293
