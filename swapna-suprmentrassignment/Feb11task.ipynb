# %%
shopping_cart={1:'Groceries',2:'Apparel',3:'Footwears',4:'Electronics'}
print(shopping_cart[4])
shopping_cart.pop(2)
print("Updated Cart:",shopping_cart)
print(shopping_cart.items())
print(len(shopping_cart))
# Out:
# Electronics
# Updated Cart: {1: 'Groceries', 3: 'Footwears', 4: 'Electronics'}
# dict_items([(1, 'Groceries'), (3, 'Footwears'), (4, 'Electronics')])
# 3
