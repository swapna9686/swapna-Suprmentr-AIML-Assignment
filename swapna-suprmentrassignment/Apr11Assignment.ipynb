# %% [markdown]
# 🔹5 Uses of Face/Object Detection:
#
# Face unlock in phones
# CCTV surveillance
# Self-driving cars
# Attendance systems in schools
# Medical imaging diagnosis
#
# 🔹 One Solution Design
# Smart Classroom Attendance System
#
# Idea:
#
# Camera detects student faces
# Matches with database
# Automatically marks attendance
