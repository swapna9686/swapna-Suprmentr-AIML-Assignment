# %% [markdown]
# Sentence:
# i luv coding 💻🔥 but sometiems error comes 😭
#
# Issues:
# Slang: luv → love
# Emoji: 💻🔥😭
# Typo: sometiems → sometimes
#
# Preprocessing Needed:
#
# 1.Lowercasing
# "Luv" → "luv"
#
# 2.Remove emojis
# 💻🔥😭 removed
#
# 3.Fix slang
# luv → love
#
# 4.Correct typos
# sometiems → sometimes
#
# 5.Remove stopwords
# “but”, “i”
