# %%
import numpy as np
temperature=[28,32,30,37,26,38]
arr=np.array(temperature)
print(np.max(arr))
print(np.min(arr))
print(np.mean(arr))
print("The last 3 days temperature is:",arr[-3::])
# Out:
# 38
# 26
# 31.833333333333332
# The last 3 days temperature is: [37 26 38]
